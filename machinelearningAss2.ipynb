# %% [markdown]
# ### Data Types and Data Structures

# %% [markdown]
# ### Assignment 2

# %% [markdown]
# ### Data Types(Number Types)

# %%
a = 30; #integer data type
b = 56;
print(a, b)
# Out:
# 30 56

# %%
x = 3.142; #float data type
y = 3.33
print (x, y)
# Out:
# 3.142 3.33

# %%
x = 7j # complex numbers data types
print(x)
# Out:
# 7j

# %% [markdown]
# ### Data Types(Boolean Types)

# %%
Idonor = True
joy = False 
print (Idonor)
# Out:
# True

# %%
type(Idonor)
# Out:
# bool

# %% [markdown]
# ### Data Types(String)

# %%
name = "Ejiroghene"
print (name)
# Out:
# Ejiroghene

# %%
type(name)
# Out:
# str

# %% [markdown]
# ### Data Structure(List)

# %%
food = ["sharwama ", "chicken"]
print (food)
# Out:
# ['sharwama ', 'chicken']

# %%
type(food)
# Out:
# list

# %% [markdown]
# ### Data Structure (Sets)

# %%
course = {"maths", "physics"}
print(course)
# Out:
# {'physics', 'maths'}

# %%
type(course)
# Out:
# set

# %% [markdown]
# ### Data Structure(Tuples)

# %%
car = ("benz", "SUV")
print(car)
# Out:
# ('benz', 'SUV')

# %%
type(car)
# Out:
# tuple

# %% [markdown]
# ### Data Structure (Dictionary)

# %%
person = {"name":"Idonor","age":19,"color":"Fair"}
print(person)
# Out:
# {'name': 'Idonor', 'age': 19, 'color': 'Fair'}

# %%
type(person)
# Out:
# dict
